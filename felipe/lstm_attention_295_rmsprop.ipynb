# %% [markdown]
# <a href="https://colab.research.google.com/github/linkjavier/disco/blob/felipe/felipe/lstm_attention_295_rmsprop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# From book: Generative AI with Python and TensorFlow 2 By Joseph Babcock and Raghav Bali
#
# LSTM-Attention Model for Music Generation

# %%
import os
import pickle
import numpy as np
from music21 import note, chord, corpus, converter, stream, instrument
import glob
from tensorflow.keras.utils import to_categorical
from tqdm.notebook import tqdm

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import LSTM, Input, Dropout, Dense, Activation, Embedding, Concatenate, Reshape
from tensorflow.keras.layers import Flatten, RepeatVector, Permute, TimeDistributed
from tensorflow.keras.layers import Multiply, Lambda, Softmax
import tensorflow.keras.backend as K 
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop

# %%
# !unzip '/content/drive/MyDrive/classical_music_midi_295.zip'
# Out:
# Archive:  /content/drive/MyDrive/classical_music_midi_295.zip
#    creating: classical_music_midi_295/
#   inflating: classical_music_midi_295/alb_esp1.mid
#   inflating: classical_music_midi_295/alb_esp2.mid
#   inflating: classical_music_midi_295/alb_esp3.mid
#   inflating: classical_music_midi_295/alb_esp4.mid
#   inflating: classical_music_midi_295/alb_esp5.mid
#   inflating: classical_music_midi_295/alb_esp6.mid
#   inflating: classical_music_midi_295/alb_se1.mid
#   inflating: classical_music_midi_295/alb_se2.mid
#   inflating: classical_music_midi_295/alb_se3.mid
#   inflating: classical_music_midi_295/alb_se4.mid
#   inflating: classical_music_midi_295/alb_se5.mid
#   inflating: classical_music_midi_295/alb_se6.mid
#   inflating: classical_music_midi_295/alb_se7.mid
#   inflating: classical_music_midi_295/alb_se8.mid
#   inflating: classical_music_midi_295/bach_846.mid
#   inflating: classical_music_midi_295/bach_847.mid
#   inflating: classical_music_midi_295/bach_850.mid
#   inflating: classical_music_midi_295/islamei.mid
#   inflating: classical_music_midi_295/appass_1.mid
#   inflating: classical_music_midi_295/appass_2.mid
#   inflating: classical_music_midi_295/appass_3.mid
#   inflating: classical_music_midi_295/beethoven_hammerklavier_1.mid
#   inflating: classical_music_midi_295/beethoven_hammerklavier_2.mid
#   inflating: classical_music_midi_295/beethoven_hammerklavier_3.mid
#   inflating: classical_music_midi_295/beethoven_hammerklavier_4.mid
#   inflating: classical_music_midi_295/beethoven_les_adieux_1.mid
#   inflating: classical_music_midi_295/beethoven_les_adieux_2.mid
#   inflating: classical_music_midi_295/beethoven_les_adieux_3.mid
#   inflating: classical_music_midi_295/beethoven_opus10_1.mid
#   inflating: classical_music_midi_295/beethoven_opus10_2.mid
#   inflating: classical_music_midi_295/beethoven_opus10_3.mid
#   inflating: classical_music_midi_295/beethoven_opus22_1.mid
#   inflating: classical_music_midi_295/beethoven_opus22_2.mid
#   inflating: classical_music_midi_295/beethoven_opus22_3.mid
#   inflating: classical_music_midi_295/beethoven_opus22_4.mid
#   inflating: classical_music_midi_295/beethoven_opus90_1.mid
#   inflating: classical_music_midi_295/beethoven_opus90_2.mid
#   inflating: classical_music_midi_295/elise.mid
#   inflating: classical_music_midi_295/mond_1.mid
#   inflating: classical_music_midi_295/mond_2.mid
#   inflating: classical_music_midi_295/mond_3.mid
#   inflating: classical_music_midi_295/pathetique_1.mid
#   inflating: classical_music_midi_295/pathetique_2.mid
#   inflating: classical_music_midi_295/pathetique_3.mid
#   inflating: classical_music_midi_295/waldstein_1.mid
#   inflating: classical_music_midi_295/waldstein_2.mid
#   inflating: classical_music_midi_295/waldstein_3.mid
#   inflating: classical_music_midi_295/bor_ps1.mid
#   inflating: classical_music_midi_295/bor_ps2.mid
#   inflating: classical_music_midi_295/bor_ps3.mid
#   inflating: classical_music_midi_295/bor_ps4.mid
#   inflating: classical_music_midi_295/bor_ps5.mid
#   inflating: classical_music_midi_295/bor_ps6.mid
#   inflating: classical_music_midi_295/bor_ps7.mid
#   inflating: classical_music_midi_295/BR_IM6.MID
#   inflating: classical_music_midi_295/br_im2.mid
#   inflating: classical_music_midi_295/br_im5.mid
#   inflating: classical_music_midi_295/br_rhap.mid
#   inflating: classical_music_midi_295/brahms_opus117_1.mid
#   inflating: classical_music_midi_295/brahms_opus117_2.mid
#   inflating: classical_music_midi_295/brahms_opus1_1.mid
#   inflating: classical_music_midi_295/brahms_opus1_2.mid
#   inflating: classical_music_midi_295/brahms_opus1_3.mid
#   inflating: classical_music_midi_295/brahms_opus1_4.mid
#   inflating: classical_music_midi_295/burg_agitato.mid
#   inflating: classical_music_midi_295/burg_erwachen.mid
#   inflating: classical_music_midi_295/burg_geschwindigkeit.mid
#   inflating: classical_music_midi_295/burg_gewitter.mid
#   inflating: classical_music_midi_295/burg_perlen.mid
#   inflating: classical_music_midi_295/burg_quelle.mid
#   inflating: classical_music_midi_295/burg_spinnerlied.mid
#   inflating: classical_music_midi_295/burg_sylphen.mid
#   inflating: classical_music_midi_295/burg_trennung.mid
#   inflating: classical_music_midi_295/chp_op18.mid
#   inflating: classical_music_midi_295/chp_op31.mid
#   inflating: classical_music_midi_295/chpn-p1.mid
#   inflating: classical_music_midi_295/chpn-p10.mid
#   inflating: classical_music_midi_295/chpn-p11.mid
#   inflating: classical_music_midi_295/chpn-p12.mid
#   inflating: classical_music_midi_295/chpn-p13.mid
#   inflating: classical_music_midi_295/chpn-p14.mid
#   inflating: classical_music_midi_295/chpn-p15.mid
#   inflating: classical_music_midi_295/chpn-p16.mid
#   inflating: classical_music_midi_295/chpn-p17.mid
#   inflating: classical_music_midi_295/chpn-p18.mid
#   inflating: classical_music_midi_295/chpn-p19.mid
#   inflating: classical_music_midi_295/chpn-p2.mid
#   inflating: classical_music_midi_295/chpn-p20.mid
#   inflating: classical_music_midi_295/chpn-p21.mid
#   inflating: classical_music_midi_295/chpn-p22.mid
#   inflating: classical_music_midi_295/chpn-p23.mid
#   inflating: classical_music_midi_295/chpn-p24.mid
#   inflating: classical_music_midi_295/chpn-p3.mid
#   inflating: classical_music_midi_295/chpn-p4.mid
#   inflating: classical_music_midi_295/chpn-p5.mid
#   inflating: classical_music_midi_295/chpn-p6.mid
#   inflating: classical_music_midi_295/chpn-p7.mid
#   inflating: classical_music_midi_295/chpn-p8.mid
#   inflating: classical_music_midi_295/chpn-p9.mid
#   inflating: classical_music_midi_295/chpn_op10_e01.mid
#   inflating: classical_music_midi_295/chpn_op10_e05.mid
#   inflating: classical_music_midi_295/chpn_op10_e12.mid
#   inflating: classical_music_midi_295/chpn_op23.mid
#   inflating: classical_music_midi_295/chpn_op25_e1.mid
#   inflating: classical_music_midi_295/chpn_op25_e11.mid
#   inflating: classical_music_midi_295/chpn_op25_e12.mid
#   inflating: classical_music_midi_295/chpn_op25_e2.mid
#   inflating: classical_music_midi_295/chpn_op25_e3.mid
#   inflating: classical_music_midi_295/chpn_op25_e4.mid
#   inflating: classical_music_midi_295/chpn_op27_1.mid
#   inflating: classical_music_midi_295/chpn_op27_2.mid
#   inflating: classical_music_midi_295/chpn_op33_2.mid
#   inflating: classical_music_midi_295/chpn_op33_4.mid
#   inflating: classical_music_midi_295/chpn_op35_1.mid
#   inflating: classical_music_midi_295/chpn_op35_2.mid
#   inflating: classical_music_midi_295/chpn_op35_3.mid
#   inflating: classical_music_midi_295/chpn_op35_4.mid
#   inflating: classical_music_midi_295/chpn_op53.mid
#   inflating: classical_music_midi_295/chpn_op66.mid
#   inflating: classical_music_midi_295/chpn_op7_1.mid
#   inflating: classical_music_midi_295/chpn_op7_2.mid
#   inflating: classical_music_midi_295/gra_esp_2.mid
#   inflating: classical_music_midi_295/gra_esp_3.mid
#   inflating: classical_music_midi_295/gra_esp_4.mid
#   inflating: classical_music_midi_295/grieg_album.mid
#   inflating: classical_music_midi_295/grieg_berceuse.mid
#   inflating: classical_music_midi_295/grieg_brooklet.mid
#   inflating: classical_music_midi_295/grieg_butterfly.mid
#   inflating: classical_music_midi_295/grieg_elfentanz.mid
#   inflating: classical_music_midi_295/grieg_halling.mid
#   inflating: classical_music_midi_295/grieg_kobold.mid
#   inflating: classical_music_midi_295/grieg_march.mid
#   inflating: classical_music_midi_295/grieg_once_upon_a_time.mid
#   inflating: classical_music_midi_295/grieg_spring.mid
#   inflating: classical_music_midi_295/grieg_voeglein.mid
#   inflating: classical_music_midi_295/grieg_waechter.mid
#   inflating: classical_music_midi_295/grieg_walzer.mid
#   inflating: classical_music_midi_295/grieg_wanderer.mid
#   inflating: classical_music_midi_295/grieg_wedding.mid
#   inflating: classical_music_midi_295/grieg_zwerge.mid
#   inflating: classical_music_midi_295/hay_40_1.mid
#   inflating: classical_music_midi_295/hay_40_2.mid
#   inflating: classical_music_midi_295/haydn_33_1.mid
#   inflating: classical_music_midi_295/haydn_33_2.mid
#   inflating: classical_music_midi_295/haydn_33_3.mid
#   inflating: classical_music_midi_295/haydn_35_1.mid
#   inflating: classical_music_midi_295/haydn_35_2.mid
#   inflating: classical_music_midi_295/haydn_35_3.mid
#   inflating: classical_music_midi_295/haydn_43_1.mid
#   inflating: classical_music_midi_295/haydn_43_2.mid
#   inflating: classical_music_midi_295/haydn_43_3.mid
#   inflating: classical_music_midi_295/haydn_7_1.mid
#   inflating: classical_music_midi_295/haydn_7_2.mid
#   inflating: classical_music_midi_295/haydn_7_3.mid
#   inflating: classical_music_midi_295/haydn_8_1.mid
#   inflating: classical_music_midi_295/haydn_8_2.mid
#   inflating: classical_music_midi_295/haydn_8_3.mid
#   inflating: classical_music_midi_295/haydn_8_4.mid
#   inflating: classical_music_midi_295/haydn_9_1.mid
#   inflating: classical_music_midi_295/haydn_9_2.mid
#   inflating: classical_music_midi_295/haydn_9_3.mid
#   inflating: classical_music_midi_295/liz_donjuan.mid
#   inflating: classical_music_midi_295/liz_et1.mid
#   inflating: classical_music_midi_295/liz_et2.mid
#   inflating: classical_music_midi_295/liz_et3.mid
#   inflating: classical_music_midi_295/liz_et4.mid
#   inflating: classical_music_midi_295/liz_et5.mid
#   inflating: classical_music_midi_295/liz_et6.mid
#   inflating: classical_music_midi_295/liz_et_trans4.mid
#   inflating: classical_music_midi_295/liz_et_trans5.mid
#   inflating: classical_music_midi_295/liz_et_trans8.mid
#   inflating: classical_music_midi_295/liz_liebestraum.mid
#   inflating: classical_music_midi_295/liz_rhap02.mid
#   inflating: classical_music_midi_295/liz_rhap09.mid
#   inflating: classical_music_midi_295/liz_rhap10.mid
#   inflating: classical_music_midi_295/liz_rhap12.mid
#   inflating: classical_music_midi_295/liz_rhap15.mid
#   inflating: classical_music_midi_295/mendel_op19_1.mid
#   inflating: classical_music_midi_295/mendel_op19_2.mid
#   inflating: classical_music_midi_295/mendel_op19_3.mid
#   inflating: classical_music_midi_295/mendel_op19_4.mid
#   inflating: classical_music_midi_295/mendel_op19_5.mid
#   inflating: classical_music_midi_295/mendel_op19_6.mid
#   inflating: classical_music_midi_295/mendel_op30_1.mid
#   inflating: classical_music_midi_295/mendel_op30_2.mid
#   inflating: classical_music_midi_295/mendel_op30_3.mid
#   inflating: classical_music_midi_295/mendel_op30_4.mid
#   inflating: classical_music_midi_295/mendel_op30_5.mid
#   inflating: classical_music_midi_295/mendel_op53_5.mid
#   inflating: classical_music_midi_295/mendel_op62_3.mid
#   inflating: classical_music_midi_295/mendel_op62_4.mid
#   inflating: classical_music_midi_295/mendel_op62_5.mid
#   inflating: classical_music_midi_295/mz_311_1.mid
#   inflating: classical_music_midi_295/mz_311_2.mid
#   inflating: classical_music_midi_295/mz_311_3.mid
#   inflating: classical_music_midi_295/mz_330_1.mid
#   inflating: classical_music_midi_295/mz_330_2.mid
#   inflating: classical_music_midi_295/mz_330_3.mid
#   inflating: classical_music_midi_295/mz_331_1.mid
#   inflating: classical_music_midi_295/mz_331_2.mid
#   inflating: classical_music_midi_295/mz_331_3.mid
#   inflating: classical_music_midi_295/mz_332_1.mid
#   inflating: classical_music_midi_295/mz_332_2.mid
#   inflating: classical_music_midi_295/mz_332_3.mid
#   inflating: classical_music_midi_295/mz_333_1.mid
#   inflating: classical_music_midi_295/mz_333_2.mid
#   inflating: classical_music_midi_295/mz_333_3.mid
#   inflating: classical_music_midi_295/mz_545_1.mid
#   inflating: classical_music_midi_295/mz_545_2.mid
#   inflating: classical_music_midi_295/mz_545_3.mid
#   inflating: classical_music_midi_295/mz_570_1.mid
#   inflating: classical_music_midi_295/mz_570_2.mid
#   inflating: classical_music_midi_295/mz_570_3.mid
#   inflating: classical_music_midi_295/muss_1.mid
#   inflating: classical_music_midi_295/muss_2.mid
#   inflating: classical_music_midi_295/muss_3.mid
#   inflating: classical_music_midi_295/muss_4.mid
#   inflating: classical_music_midi_295/muss_5.mid
#   inflating: classical_music_midi_295/muss_6.mid
#   inflating: classical_music_midi_295/muss_7.mid
#   inflating: classical_music_midi_295/muss_8.mid
#   inflating: classical_music_midi_295/schu_143_1.mid
#   inflating: classical_music_midi_295/schu_143_2.mid
#   inflating: classical_music_midi_295/schu_143_3.mid
#   inflating: classical_music_midi_295/schub_d760_1.mid
#   inflating: classical_music_midi_295/schub_d760_2.mid
#   inflating: classical_music_midi_295/schub_d760_3.mid
#   inflating: classical_music_midi_295/schub_d760_4.mid
#   inflating: classical_music_midi_295/schub_d960_1.mid
#   inflating: classical_music_midi_295/schub_d960_2.mid
#   inflating: classical_music_midi_295/schub_d960_3.mid
#   inflating: classical_music_midi_295/schub_d960_4.mid
#   inflating: classical_music_midi_295/schubert_D850_1.mid
#   inflating: classical_music_midi_295/schubert_D850_2.mid
#   inflating: classical_music_midi_295/schubert_D850_3.mid
#   inflating: classical_music_midi_295/schubert_D850_4.mid
#   inflating: classical_music_midi_295/schubert_D935_1.mid
#   inflating: classical_music_midi_295/schubert_D935_2.mid
#   inflating: classical_music_midi_295/schubert_D935_3.mid
#   inflating: classical_music_midi_295/schubert_D935_4.mid
#   inflating: classical_music_midi_295/schuim-1.mid
#   inflating: classical_music_midi_295/schuim-2.mid
#   inflating: classical_music_midi_295/schuim-3.mid
#   inflating: classical_music_midi_295/schuim-4.mid
#   inflating: classical_music_midi_295/schumm-1.mid
#   inflating: classical_music_midi_295/schumm-2.mid
#   inflating: classical_music_midi_295/schumm-3.mid
#   inflating: classical_music_midi_295/schumm-4.mid
#   inflating: classical_music_midi_295/schumm-5.mid
#   inflating: classical_music_midi_295/schumm-6.mid
#   inflating: classical_music_midi_295/schum_abegg.mid
#   inflating: classical_music_midi_295/scn15_1.mid
#   inflating: classical_music_midi_295/scn15_10.mid
#   inflating: classical_music_midi_295/scn15_11.mid
#   inflating: classical_music_midi_295/scn15_12.mid
#   inflating: classical_music_midi_295/scn15_13.mid
#   inflating: classical_music_midi_295/scn15_2.mid
#   inflating: classical_music_midi_295/scn15_3.mid
#   inflating: classical_music_midi_295/scn15_4.mid
#   inflating: classical_music_midi_295/scn15_5.mid
#   inflating: classical_music_midi_295/scn15_6.mid
#   inflating: classical_music_midi_295/scn15_7.mid
#   inflating: classical_music_midi_295/scn15_8.mid
#   inflating: classical_music_midi_295/scn15_9.mid
#   inflating: classical_music_midi_295/scn16_1.mid
#   inflating: classical_music_midi_295/scn16_2.mid
#   inflating: classical_music_midi_295/scn16_3.mid
#   inflating: classical_music_midi_295/scn16_4.mid
#   inflating: classical_music_midi_295/scn16_5.mid
#   inflating: classical_music_midi_295/scn16_6.mid
#   inflating: classical_music_midi_295/scn16_7.mid
#   inflating: classical_music_midi_295/scn16_8.mid
#   inflating: classical_music_midi_295/scn68_10.mid
#   inflating: classical_music_midi_295/scn68_12.mid
#   inflating: classical_music_midi_295/ty_april.mid
#   inflating: classical_music_midi_295/ty_august.mid
#   inflating: classical_music_midi_295/ty_dezember.mid
#   inflating: classical_music_midi_295/ty_februar.mid
#   inflating: classical_music_midi_295/ty_januar.mid
#   inflating: classical_music_midi_295/ty_juli.mid
#   inflating: classical_music_midi_295/ty_juni.mid
#   inflating: classical_music_midi_295/ty_maerz.mid
#   inflating: classical_music_midi_295/ty_mai.mid
#   inflating: classical_music_midi_295/ty_november.mid
#   inflating: classical_music_midi_295/ty_oktober.mid
#   inflating: classical_music_midi_295/ty_september.mid
#   inflating: classical_music_midi_295/DEB_CLAI.MID
#   inflating: classical_music_midi_295/deb_menu.mid
#   inflating: classical_music_midi_295/DEB_PASS.MID
#   inflating: classical_music_midi_295/deb_prel.mid
#   inflating: classical_music_midi_295/debussy_cc_1.mid
#   inflating: classical_music_midi_295/debussy_cc_2.mid
#   inflating: classical_music_midi_295/debussy_cc_3.mid
#   inflating: classical_music_midi_295/debussy_cc_4.mid
#   inflating: classical_music_midi_295/debussy_cc_6.mid

# %%
data_dir = 'classical_music_midi_295'

# list of files
midi_list = os.listdir(data_dir)

# Load and make list of stream objects
original_scores = []
for midi in tqdm(midi_list):
    score = converter.parse(os.path.join(data_dir,midi))
    original_scores.append(score)
# Out:
#   0%|          | 0/295 [00:00<?, ?it/s]

# %%
# Merge notes into chords
original_scores = [midi.chordify() for midi in tqdm(original_scores)]
# Out:
#   0%|          | 0/295 [00:00<?, ?it/s]

# %%
# Define empty lists of lists
original_chords = [[] for _ in original_scores]
original_durations = [[] for _ in original_scores]
original_keys = []

# Extract notes, chords, durations, and keys
for i, midi in tqdm(enumerate(original_scores)):
    original_keys.append(str(midi.analyze('key')))
    for element in midi:
        if isinstance(element, note.Note):
            original_chords[i].append(element.pitch)
            original_durations[i].append(element.duration.quarterLength)
        elif isinstance(element, chord.Chord):
            original_chords[i].append('.'.join(str(n) for n in element.pitches))
            original_durations[i].append(element.duration.quarterLength)
# Out:
# 0it [00:00, ?it/s]

# %%
# Create list of chords and durations from songs in C major
major_chords = [c for (c, k) in tqdm(zip(original_chords, original_keys)) if (k == 'C major')]
major_durations = [c for (c, k) in tqdm(zip(original_durations, original_keys)) if (k == 'C major')]
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def get_distinct(elements):
    # Get all pitch names
    element_names = sorted(set(elements))
    n_elements = len(element_names)
    return (element_names, n_elements)

def create_lookups(element_names):
    # create dictionary to map notes and durations to integers
    element_to_int = dict((element, number) for number, element in enumerate(element_names))
    int_to_element = dict((number, element) for number, element in enumerate(element_names))

    return (element_to_int, int_to_element)

# %%
store_folder = 'parsed_data'
os.mkdir(store_folder)

# %%
# get the distinct sets of notes and durations
note_names, n_notes = get_distinct([n for chord in major_chords for n in chord])
duration_names, n_durations = get_distinct([d for dur in major_durations for d in dur])
distincts = [note_names, n_notes, duration_names, n_durations]

with open(os.path.join(store_folder, 'distincts'), 'wb') as f:
    pickle.dump(distincts, f)

# %%
# make the lookup dictionaries for notes and dictionaries and save
note_to_int, int_to_note = create_lookups(note_names)
duration_to_int, int_to_duration = create_lookups(duration_names)
lookups = [note_to_int, int_to_note, duration_to_int, int_to_duration]

with open(os.path.join(store_folder, 'lookups'), 'wb') as f:
    pickle.dump(lookups, f)

# %%
# Set sequence length
sequence_length = 64

# Define empty array for train data
train_chords = []
train_durations = []
target_chords = []
target_durations = []

# Construct train and target sequences for chords and durations
for s in range(len(major_chords)):
    chord_list = [note_to_int[c] for c in major_chords[s]]
    duration_list = [duration_to_int[d] for d in major_durations[s]]
    for i in range(len(chord_list) - sequence_length):
        train_chords.append(chord_list[i:i+sequence_length])
        train_durations.append(duration_list[i:i+sequence_length])
        target_chords.append(chord_list[i+1])
        target_durations.append(duration_list[i+1])

# %%
train_chords = np.array(train_chords)
train_durations = np.array(train_durations)
target_chords = np.array(target_chords)
target_durations = np.array(target_durations)

# %%
def create_network(n_notes, n_durations, embed_size = 100, rnn_units = 256):
    """ create the structure of the neural network """

    notes_in = Input(shape = (None,))
    durations_in = Input(shape = (None,))

    x1 = Embedding(n_notes, embed_size)(notes_in)
    x2 = Embedding(n_durations, embed_size)(durations_in) 

    x = Concatenate()([x1,x2])

    x = LSTM(rnn_units, return_sequences=True)(x)

    x = LSTM(rnn_units, return_sequences=True)(x)

    # attention
    e = Dense(1, activation='tanh')(x)
    e = Reshape([-1])(e)
    alpha = Activation('softmax')(e)

    alpha_repeated = Permute([2, 1])(RepeatVector(rnn_units)(alpha))

    c = Multiply()([x, alpha_repeated])
    c = Lambda(lambda xin: K.sum(xin, axis=1), output_shape=(rnn_units,))(c)
    
                                    
    notes_out = Dense(n_notes, activation = 'softmax', name = 'pitch')(c)
    durations_out = Dense(n_durations, activation = 'softmax', name = 'duration')(c)
   
    model = Model([notes_in, durations_in], [notes_out, durations_out])
    model.compile(loss=['sparse_categorical_crossentropy', 
                        'sparse_categorical_crossentropy'], optimizer=RMSprop(learning_rate = 0.001))

    return model

# %%
embed_size = 128
rnn_units = 128

# %%
model = create_network(n_notes, n_durations, embed_size, rnn_units)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, None, 128)    860800      input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    2688        input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, 256)    0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, None, 128)    197120      concatenate[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, None, 128)    131584      lstm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 1)      129         lstm_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, None)         0           dense[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None)         0           reshape[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 128, None)    0           activation[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, None, 128)    0           repeat_vector[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, None, 128)    0           lstm_1[0][0]
#                                                                  permute[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128)          0           multiply[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 6725)         867525      lambda[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 21)           2709        lambda[0][0]
# ==================================================================================================
# Total params: 2,062,555
# Trainable params: 2,062,555
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
os.mkdir('outputs')
os.mkdir('outputs/output')
os.mkdir('outputs/weights')

# %%
output_folder = 'outputs'
weights_folder = os.path.join(output_folder, 'weights')


checkpoint = ModelCheckpoint(
    os.path.join(weights_folder, "weights.h5"),
    monitor='loss',
    verbose=0,
    save_best_only=True,
    mode='min'
)

epoch_checkpoint = ModelCheckpoint(
    os.path.join(weights_folder, "weights-{epoch:02d}-{loss:.4f}.h5"),
    monitor='loss',
    verbose=0,
    save_best_only=True,
    mode='min'
)

early_stopping = EarlyStopping(
    monitor='loss'
    , restore_best_weights=True
    , patience = 5
)


callbacks_list = [
    checkpoint
    , epoch_checkpoint
    , early_stopping
 ]

model.save_weights(os.path.join(weights_folder, "weights.h5"))

# %%
history = model.fit([train_chords, train_durations], 
                    [target_chords, target_durations]
                    , epochs=100, batch_size=128
                    , callbacks=callbacks_list
                    , shuffle=True
                  )
# Out:
# Epoch 1/100
# 256/256 [==============================] - 19s 41ms/step - loss: 8.3633 - pitch_loss: 7.6271 - duration_loss: 0.7362
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 256/256 [==============================] - 10s 41ms/step - loss: 7.5809 - pitch_loss: 7.0737 - duration_loss: 0.5072
# Epoch 3/100
# 256/256 [==============================] - 10s 41ms/step - loss: 7.3373 - pitch_loss: 6.8850 - duration_loss: 0.4523
# Epoch 4/100
# 256/256 [==============================] - 10s 41ms/step - loss: 7.0825 - pitch_loss: 6.6824 - duration_loss: 0.4001
# Epoch 5/100
# 256/256 [==============================] - 10s 41ms/step - loss: 6.8256 - pitch_loss: 6.4684 - duration_loss: 0.3571
# Epoch 6/100
# 256/256 [==============================] - 10s 41ms/step - loss: 6.5485 - pitch_loss: 6.2520 - duration_loss: 0.2966
# Epoch 7/100
# 256/256 [==============================] - 10s 41ms/step - loss: 6.2296 - pitch_loss: 6.0043 - duration_loss: 0.2253
# Epoch 8/100
# 256/256 [==============================] - 10s 41ms/step - loss: 5.8394 - pitch_loss: 5.6871 - duration_loss: 0.1523
# Epoch 9/100
# 256/256 [==============================] - 10s 41ms/step - loss: 5.4212 - pitch_loss: 5.3175 - duration_loss: 0.1037
# Epoch 10/100
# 256/256 [==============================] - 11s 41ms/step - loss: 5.0004 - pitch_loss: 4.9260 - duration_loss: 0.0744
# Epoch 11/100
# 256/256 [==============================] - 11s 41ms/step - loss: 4.6242 - pitch_loss: 4.5645 - duration_loss: 0.0597
# Epoch 12/100
# 256/256 [==============================] - 10s 41ms/step - loss: 4.2607 - pitch_loss: 4.2106 - duration_loss: 0.0502
# Epoch 13/100
# 256/256 [==============================] - 10s 41ms/step - loss: 3.9739 - pitch_loss: 3.9319 - duration_loss: 0.0420
# Epoch 14/100
# 256/256 [==============================] - 10s 41ms/step - loss: 3.7740 - pitch_loss: 3.7373 - duration_loss: 0.0367
# Epoch 15/100
# 256/256 [==============================] - 10s 41ms/step - loss: 3.5878 - pitch_loss: 3.5539 - duration_loss: 0.0339
# Epoch 16/100
# 256/256 [==============================] - 10s 41ms/step - loss: 3.3612 - pitch_loss: 3.3329 - duration_loss: 0.0283
# Epoch 17/100
# 256/256 [==============================] - 10s 41ms/step - loss: 3.2230 - pitch_loss: 3.1966 - duration_loss: 0.0264
# Epoch 18/100
# 256/256 [==============================] - 10s 41ms/step - loss: 3.1016 - pitch_loss: 3.0785 - duration_loss: 0.0230
# Epoch 19/100
# 256/256 [==============================] - 10s 41ms/step - loss: 3.0221 - pitch_loss: 3.0002 - duration_loss: 0.0220
# Epoch 20/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.9347 - pitch_loss: 2.9151 - duration_loss: 0.0195
# Epoch 21/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.8330 - pitch_loss: 2.8142 - duration_loss: 0.0189
# Epoch 22/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.7434 - pitch_loss: 2.7257 - duration_loss: 0.0177
# Epoch 23/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.6449 - pitch_loss: 2.6295 - duration_loss: 0.0154
# Epoch 24/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.5704 - pitch_loss: 2.5565 - duration_loss: 0.0140
# Epoch 25/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.5284 - pitch_loss: 2.5142 - duration_loss: 0.0142
# Epoch 26/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.4827 - pitch_loss: 2.4679 - duration_loss: 0.0148
# Epoch 27/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.4451 - pitch_loss: 2.4309 - duration_loss: 0.0142
# Epoch 28/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.4147 - pitch_loss: 2.4000 - duration_loss: 0.0146
# Epoch 29/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.3755 - pitch_loss: 2.3610 - duration_loss: 0.0145
# Epoch 30/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.3333 - pitch_loss: 2.3187 - duration_loss: 0.0146
# Epoch 31/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.2891 - pitch_loss: 2.2742 - duration_loss: 0.0149
# Epoch 32/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.2426 - pitch_loss: 2.2288 - duration_loss: 0.0138
# Epoch 33/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.2133 - pitch_loss: 2.2000 - duration_loss: 0.0133
# Epoch 34/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.1961 - pitch_loss: 2.1826 - duration_loss: 0.0134
# Epoch 35/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.1645 - pitch_loss: 2.1521 - duration_loss: 0.0124
# Epoch 36/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.1479 - pitch_loss: 2.1351 - duration_loss: 0.0128
# Epoch 37/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.1291 - pitch_loss: 2.1162 - duration_loss: 0.0129
# Epoch 38/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.1062 - pitch_loss: 2.0939 - duration_loss: 0.0123
# Epoch 39/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.0877 - pitch_loss: 2.0758 - duration_loss: 0.0119
# Epoch 40/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0583 - pitch_loss: 2.0468 - duration_loss: 0.0115
# Epoch 41/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0493 - pitch_loss: 2.0372 - duration_loss: 0.0120
# Epoch 42/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0446 - pitch_loss: 2.0323 - duration_loss: 0.0123
# Epoch 43/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0375 - pitch_loss: 2.0255 - duration_loss: 0.0120
# Epoch 44/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0299 - pitch_loss: 2.0179 - duration_loss: 0.0120
# Epoch 45/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0275 - pitch_loss: 2.0152 - duration_loss: 0.0123
# Epoch 46/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0242 - pitch_loss: 2.0124 - duration_loss: 0.0117
# Epoch 47/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0219 - pitch_loss: 2.0107 - duration_loss: 0.0112
# Epoch 48/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0234 - pitch_loss: 2.0126 - duration_loss: 0.0108
# Epoch 49/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.0272 - pitch_loss: 2.0166 - duration_loss: 0.0106
# Epoch 50/100
# 256/256 [==============================] - 11s 41ms/step - loss: 2.0368 - pitch_loss: 2.0262 - duration_loss: 0.0107
# Epoch 51/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.0446 - pitch_loss: 2.0332 - duration_loss: 0.0113
# Epoch 52/100
# 256/256 [==============================] - 10s 41ms/step - loss: 2.0535 - pitch_loss: 2.0431 - duration_loss: 0.0104

# %%
def sample_with_temp(preds, temperature):

    if temperature == 0:
        return np.argmax(preds)
    else:
        preds = np.log(preds) / temperature
        exp_preds = np.exp(preds)
        preds = exp_preds / np.sum(exp_preds)
        return np.random.choice(len(preds), p=preds)

# %%
# chord and duration sequences
initial_chords = np.expand_dims(train_chords[0,:].copy(), 0)
initial_durations = np.expand_dims(train_durations[0,:].copy(), 0)

# %%
initial_chords
# Out:
# array([[2510, 4125, 2424, 6702, 6702, 1360, 2552, 2424, 6702, 6702, 4125,
#         2510, 6392, 6392, 6297, 6297, 6162, 6593, 3220, 1308, 5099, 6702,
#         2484, 4125, 5099, 5089, 3220, 4125, 4092, 2510, 4914, 4914, 6373,
#         6373, 2323, 4025, 6642, 2273, 3993, 6593, 2273, 3993, 6593, 2323,
#         4025, 6642, 6671, 2493, 2273, 3993, 6593, 2493, 2273, 3993, 6593,
#         2493, 2273, 3993, 6593, 6639, 2335, 4036, 6654, 2493]])

# %%
initial_durations
# Out:
# array([[7, 2, 2, 2, 2, 2, 2, 2, 2, 2, 7, 2, 2, 2, 2, 2, 8, 7, 2, 2, 7, 2,
#         2, 7, 2, 2, 7, 2, 2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#         3, 0, 2, 2, 0, 3, 3, 2, 0, 3, 3, 2, 0, 3, 0, 2, 3, 3, 3, 2]])

# %%
# Function to predict chords and durations
def predict_chords(chord_sequence, duration_sequence,model,temperature=1.0):
    predicted_chords, predicted_durations = model.predict([chord_sequence, duration_sequence])
    return sample_with_temp(predicted_chords[0],temperature), sample_with_temp(predicted_durations[0],temperature)

# %%
# Define empty lists for generated chords and durations
new_chords, new_durations = [], []

# Generate chords and durations using 120 rounds of prediction
for j in range(120):
    new_chord, new_duration = predict_chords(initial_chords, 
                                             initial_durations,
                                             model,
                                             temperature=0.8)
    new_chords.append(new_chord)
    new_durations.append(new_duration)
    initial_chords[0][:-1] = initial_chords[0][1:]
    initial_chords[0][-1] = new_chord
    initial_durations[0][:-1] = initial_durations[0][1:]
    initial_durations[0][-1] = new_duration

# %%
# Create stream object
generated_stream = stream.Stream()
generated_stream.append(instrument.Piano())

# Add notes and durations to stream
for j in range(len(new_chords)):
    try:
        generated_stream.append(note.Note(int_to_note[new_chords[j]].replace('.', ' '), 
                                          quarterType = int_to_duration[new_durations[j]]))
    except:
        generated_stream.append(chord.Chord(int_to_note[new_chords[j]].replace('.', ' '), 
                                            quarterType = int_to_duration[new_durations[j]]))

# Export as MIDI file
generated_stream.write('midi', fp='lstm_att_295_100_ep.mid')
# Out:
# 'lstm_att_295_100_ep.mid'
